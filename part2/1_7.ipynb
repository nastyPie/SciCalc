# %% [markdown]
# # КМ1
#
#
# 1) Загрузить цветное изображение енота. Каждый пиксел изображения имеет три составляющие: красную зеленую и синюю. Сделать из цветного изображения три черно-белых. Отобразить их и сравнить между собой. Циклы не использовать.
#
# 2) С получившимися тремя черно-белыми изображениями выполнить следующие действия: первое перевернуть кверху ногами, второе отразить относительно оси ординат, третье инвертировать, т.е. заменить 0 на 255, 255 на 0, а 100 на 255-100=155. Циклы не использовать. Отобразить получившееся.

# %%
from scipy.misc import face
import matplotlib.pyplot as plt


f = face()
f1 = f[:, :, 0]
f2 = f[:, :, 1]
f3 = f[:, :, 2]
plt.imshow(f1, cmap='gray')

# %%
plt.imshow(f2, cmap='gray')

# %%
plt.imshow(f3, cmap='gray')

# %% [markdown]
# ## Задание 2

# %%
plt.imshow(f1[::-1], cmap='gray')

# %%
plt.imshow(f2[:, ::-1], cmap='gray')

# %%
plt.imshow(255 - f3, cmap='gray')
